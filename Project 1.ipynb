# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel('MOH KKM.xlsx', sheet_name='States')
data.shape
# Out:
# (9840, 25)

# %%
data.tail()
# Out:
#            date              state  Daily Tests  Daily Cases  Hospitalisation  \
# 9835 2021-09-30           Selangor          0.0         1940           1235.0
# 9836 2021-09-30         Terengganu          0.0          726            289.0
# 9837 2021-09-30  W.P. Kuala Lumpur          0.0          258            341.0
# 9838 2021-09-30        W.P. Labuan          0.0            1              1.0
# 9839 2021-09-30     W.P. Putrajaya          0.0           28             64.0
#
#         ICU  Ventilators  Daily Death  BID  Actual Death  ...  \
# 9835   10.0          3.0           18    5             1  ...
# 9836   84.0         53.0            8    1             1  ...
# 9837  122.0         50.0            7    1             1  ...
# 9838  109.0         46.0            0    0             0  ...
# 9839  157.0         91.0            0    0             0  ...
#
#       Cummulative First Dose  Cummulative Complete Dose  Unnamed: 17  Test %  \
# ...

# %%
data.describe()
# Out:
#         Daily Tests  Daily Cases  Hospitalisation          ICU  Ventilators  Daily Death  \
# count   1472.000000  9840.000000      8484.000000  8484.000000  8484.000000  9840.000000
# mean    8428.197690   228.221037       279.900636    27.526167    14.903937     2.676321
# std     9318.469214   639.124277       482.728796    55.648468    31.912161    11.386912
# min        0.000000     0.000000         0.000000     0.000000     0.000000     0.000000
# 25%     3281.500000     0.000000        12.000000     0.000000     0.000000     0.000000
# 50%     6157.000000     8.000000        90.000000     4.000000     2.000000     0.000000
# 75%     9892.250000   156.000000       355.250000    32.000000    16.000000     1.000000
# max    56501.000000  8792.000000      4455.000000   541.000000   303.000000   359.000000
#
#                BID  Actual Death    Recovered  New Cases Cumulative  ...  Cummulative First Dose  \
# ...
